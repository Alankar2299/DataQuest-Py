# %% [markdown]
# # Task_01

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Python Datatype practice

# %%
x = 50

# %%
y = 50

# %%
x+y
# Out:
# 100

# %%
x = 200

# %%
y = 100

# %%
x-y
# Out:
# 100

# %%
x = 500

# %%
y = 5

# %%
x/5
# Out:
# 100.0

# %%
x = 0.005

# %%
y = 0.05

# %%
x/y
# Out:
# 0.09999999999999999

# %%
x = 'python is '

# %%
y = 'fun!!!'

# %%
x+y
# Out:
# 'python is fun!!!'

# %%
x = ' I am very happy today.'

# %%
y = 'Because Aylin sorted the Jupyter issue!!'

# %%
x + y
# Out:
# ' I am very happy today.Because Aylin sorted the Jupyter issue!!'

# %%
X = 'tok'

# %%
X * 100
# Out:
# '...'

# %% [markdown]
# ### End of task
